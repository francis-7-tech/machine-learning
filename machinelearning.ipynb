# %%
import pandas as pd

# %% [markdown]
# *****************************************************

# %% [markdown]
# **Step 2: Import and Inspect the Data**

# %%
data=pd.read_csv(r"C:\Users\Francis\Desktop\archive\house_data.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
data=pd.read_csv(r"C:\Users\Francis\Desktop\archive\house_data.csv")
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
data=pd.read_csv(r"C:\Users\Francis\Desktop\archive\house_data.csv")
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
data=pd.read_csv(r"C:\Users\Francis\Desktop\archive\house_data.csv")
data.shape
# Out:
# (21613, 21)

# %% [markdown]
# ********************************************************

# %% [markdown]
# **Step 3: Clean and Preprocess the Data**

# %%
print("Missing values:")
print(data.isnull().sum())
# Out:
# Missing values:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
data.drop_duplicates()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
# Convert 'date' to datetime
data['date'] = pd.to_datetime(data['date'])

# Extract year and month
data['year'] = data['date'].dt.year
data['month'] = data['date'].dt.month

# Drop the original date column
data = data.drop('date', axis=1)

# %%
categorical_cols = ['waterfront', 'view', 'condition', 'grade']

for col in categorical_cols:
    data[col] = data[col].astype('category').cat.codes

# %%
from sklearn.preprocessing import MinMaxScaler

# Select numeric columns only
numeric_cols = data.select_dtypes(include=['int64', 'float64']).columns
numeric_cols = numeric_cols.drop('price')  # Exclude target variable

scaler = MinMaxScaler()
data[numeric_cols] = scaler.fit_transform(data[numeric_cols])

# %%
data=pd.read_csv(r"C:\Users\Francis\Desktop\archive\house_data.csv")
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# ****************************************

# %% [markdown]
# **Step 4: Conduct Basic EDA**

# %%
# General descriptive statistics for numeric columns
print(data.describe())
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
# Check price distribution
print("Price range:")
print("Min price:", data['price'].min())
print("Max price:", data['price'].max())
print("Average price:", data['price'].mean())

# Quick look at the distribution
import matplotlib.pyplot as plt

plt.hist(data['price'], bins=50)
plt.xlabel('Price')
plt.ylabel('Number of Houses')
plt.title('House Price Distribution')
plt.show()
# Out:
# Price range:
# Min price: 75000.0
# Max price: 7700000.0
# Average price: 540088.1417665294

# %%
# Group by 'bedrooms' and show average price
bedroom_price = data.groupby('bedrooms')['price'].mean()
print(bedroom_price)

# Plot it
bedroom_price.plot(kind='bar')
plt.xlabel('Number of Bedrooms')
plt.ylabel('Average Price')
plt.title('Average House Price by Bedrooms')
plt.show()
# Out:
# bedrooms
# 0     4.095038e+05
# 1     3.176429e+05
# 2     4.013727e+05
# 3     4.662321e+05
# 4     6.354195e+05
# 5     7.865998e+05
# 6     8.255206e+05
# 7     9.511847e+05
# 8     1.105077e+06
# 9     8.939998e+05
# 10    8.193333e+05
# 11    5.200000e+05
# 33    6.400000e+05
# Name: price, dtype: float64

# %%
# Select only numeric columns
numeric_data = data.select_dtypes(include=['number'])

# Now calculate correlation matrix
correlation_matrix = numeric_data.corr()

# Show correlations with 'price'
print(correlation_matrix['price'].sort_values(ascending=False))
# Out:
# price            1.000000
# sqft_living      0.702035
# grade            0.667434
# sqft_above       0.605567
# sqft_living15    0.585379
# bathrooms        0.525138
# view             0.397293
# sqft_basement    0.323816
# bedrooms         0.308350
# lat              0.307003
# waterfront       0.266369
# floors           0.256794
# yr_renovated     0.126434
# sqft_lot         0.089661
# sqft_lot15       0.082447
# yr_built         0.054012
# condition        0.036362
# long             0.021626
# id              -0.016762
# zipcode         -0.053203
# Name: price, dtype: float64

# %%
import seaborn as sns

plt.figure(figsize=(12,10))
sns.heatmap(correlation_matrix, cmap='coolwarm', annot=True)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# **Step 5: Visualize the Data. Create atleast 5 Visualizations**

# %% [markdown]
# *****************************

# %% [markdown]
# **Histogram of House Prices (Matplotlib)**

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.hist(data['price'], bins=50, color='skyblue', edgecolor='black')
plt.title('Distribution of House Prices')
plt.xlabel('Price')
plt.ylabel('Number of Houses')
plt.show()

# %% [markdown]
# **Histogram of House Prices:
# This histogram shows the distribution of house prices in the dataset.
# Most houses are priced below $1,000,000, with fewer luxury homes priced above that.**

# %% [markdown]
# *********************************************

# %% [markdown]
# **Bar Chart: Average Price by Number of Bedrooms (Matplotlib)**

# %%
# Group and calculate average price
bedroom_avg_price = data.groupby('bedrooms')['price'].mean()

plt.figure(figsize=(10,6))
bedroom_avg_price.plot(kind='bar', color='lightgreen', edgecolor='black')
plt.title('Average House Price by Bedrooms')
plt.xlabel('Number ofbb Bedrooms')
plt.ylabel('Average Price')
plt.show()

# %% [markdown]
# **Average Price by Bedrooms:
# The bar chart shows that houses with 3–5 bedrooms generally have higher average prices.
# However, adding too many bedrooms (like 10+) doesn't guarantee a much higher price.**

# %% [markdown]
# ******************

# %% [markdown]
#  **Boxplot: Price Distribution by Number of Bathrooms (Seaborn)**

# %%
import seaborn as sns

plt.figure(figsize=(12,6))
sns.boxplot(x='bathrooms', y='price', data=data)
plt.title('House Price Distribution by Number of Bathrooms')
plt.xlabel('Number of Bathrooms')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# **Price vs Bathrooms:
# Houses with more bathrooms tend to have higher prices, but there are many outliers.
# Boxplots also reveal that the price variation increases for homes with 3+ bathrooms.**

# %% [markdown]
# **********************************

# %% [markdown]
# **Scatterplot: Living Area (sqft) vs Price (Seaborn)**

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x='sqft_living', y='price', data=data, alpha=0.5)
plt.title('Relationship Between Sqft Living and House Price')
plt.xlabel('Living Area (sqft)')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# **Living Area vs Price:
# There is a positive correlation between the size of the living area and the house price.
# Larger houses generally cost more, but there are a few very large homes priced unusually high (outliers).**

# %% [markdown]
# *******************************************************

# %% [markdown]
# **Pairplot of Selected Features (Seaborn)**

# %%
# Choose a few important columns
selected_columns = ['price', 'sqft_living', 'bedrooms', 'bathrooms', 'grade']

sns.pairplot(data[selected_columns])
plt.suptitle('Pairplot of Important Features', y=1.02)
plt.show()
# Out:
# C:\Users\Francis\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# **Pairplot Analysis:
# This pairplot shows the relationships among house price, size, number of bedrooms, bathrooms, and grade.
# Higher grades and bigger living spaces clearly lead to higher house prices.**

# %% [markdown]
# **********************************************

# %% [markdown]
# **Step 6: Apply Machine Learning Analysis**

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Select important features (you can add more features if you want)
features = ['sqft_living', 'bedrooms', 'bathrooms', 'floors', 'grade']
X = data[features]

# Target variable
y = data['price']

# %%
# Split the dataset: 70% training, 30% testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Create the model
model = LinearRegression()

# Train the model
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict on the test data
y_pred = model.predict(X_test)

# %%
# Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)

# Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Root Mean Squared Error (RMSE)
rmse = mean_squared_error(y_test, y_pred, squared=False)

# R-squared (R2 Score)
r2 = r2_score(y_test, y_pred)

# Print the results
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"R-squared (R2 Score): {r2:.4f}")
# Out:
# Mean Absolute Error (MAE): 166122.85
# Mean Squared Error (MSE): 66651967392.62
# Root Mean Squared Error (RMSE): 258170.42
# R-squared (R2 Score): 0.5383

# %%
import pandas as pd

# Create a DataFrame for metrics
metrics_df = pd.DataFrame({
    'Metric': ['Mean Absolute Error', 'Mean Squared Error', 'Root Mean Squared Error', 'R2 Score'],
    'Value': [mae, mse, rmse, r2]
})

metrics_df
# Out:
#                     Metric         Value
# 0      Mean Absolute Error  1.661229e+05
# 1       Mean Squared Error  6.665197e+10
# 2  Root Mean Squared Error  2.581704e+05
# 3                 R2 Score  5.383143e-01

# %%
import pandas as pd

# Create a DataFrame for metrics
metrics_df = pd.DataFrame({
    'Metric': ['Mean Absolute Error', 'Mean Squared Error', 'Root Mean Squared Error', 'R2 Score'],
    'Value': [mae, mse, rmse, r2]
})

metrics_df
# Out:
#                     Metric         Value
# 0      Mean Absolute Error  1.661229e+05
# 1       Mean Squared Error  6.665197e+10
# 2  Root Mean Squared Error  2.581704e+05
# 3                 R2 Score  5.383143e-01

# %%
plt.figure(figsize=(10,6))
plt.scatter(y_test, y_pred, alpha=0.5, color='teal')
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.title('Actual vs Predicted House Prices')
plt.grid(True)
plt.show()

# %% [markdown]
# ********************************************
